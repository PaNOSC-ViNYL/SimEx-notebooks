# %%
from SimEx.Analysis.XFELPhotonAnalysis import XFELPhotonAnalysis
from SimEx.Analysis.DiffractionAnalysis import DiffractionAnalysis

# %%
beam_analysis = XFELPhotonAnalysis(input_path='./initial_wavefront.h5')
beam_analysis.plotTotalPower()
beam_analysis.plotIntensityMap()
# Out:
#  Start initialization.
#
#  Loading wavefront from ./initial_wavefront.h5.
#  ... done.
#
#  Getting intensities.
#  ... done.
#  Data dimensions =  (400, 400, 30)
#
#  Masking NANs.
#  ... done.
#
#  Plotting total power.
# Pulse energy 2e-06 J
#
#  Plotting intensity map.
# R-space

# %%
beam_analysis = XFELPhotonAnalysis(input_path='./prop_out.h5')
beam_analysis.plotTotalPower()
beam_analysis.plotIntensityMap()
# Out:
#  Start initialization.
#
#  Loading wavefront from ./prop_out.h5.
#  ... done.
#
#  Getting intensities.
#  ... done.
#  Data dimensions =  (162, 324, 30)
#
#  Masking NANs.
#  ... done.
#
#  Plotting total power.
# Pulse energy 1.1e-08 J
#
#  Plotting intensity map.
# R-space

# %%
spi_analysis = DiffractionAnalysis('diffr.h5',
                                   pattern_indices=[1],
                                   poissonize=False)
spi_analysis.plotPattern(logscale=True)
# Out:
# (<Figure size 432x288 with 2 Axes>,
#  <AxesSubplot:xlabel='$x$ (pixel)', ylabel='$y$ (pixel)'>)
