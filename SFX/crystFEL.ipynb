# %% [markdown]
# # Multi-panel detector

# %% [markdown]
# The AGIPD detector, which is already in use at the SPB experiment, consists of 16 modules of 512×128 pixels each. Each module is further divided into 8 ASICs (application-specific integrated circuit).

# %% [markdown]
# <img src="https://github.com/PaNOSC-ViNYL/M5.2DEMO/blob/master/simex/SFX/AGIPD.png?raw=true" width="300" align="left"/> <img src="https://github.com/PaNOSC-ViNYL/M5.2DEMO/blob/master/simex/SFX/agipd_geometry_14_1.png?raw=true" width="420" align="right"/>
#
# <div style="clear: both"><small>Photo © European XFEL</small></div>

# %% [markdown]
# ## Simulation Demonstration

# %%
import os, shutil, sys
import h5py
import matplotlib.pyplot as plt
import numpy as np
from extra_geom import AGIPD_1MGeometry

# %%
from SimEx.Calculators.AbstractPhotonDiffractor import AbstractPhotonDiffractor
from SimEx.Calculators.CrystFELPhotonDiffractor import CrystFELPhotonDiffractor
from SimEx.Parameters.CrystFELPhotonDiffractorParameters import CrystFELPhotonDiffractorParameters
from SimEx.Parameters.PhotonBeamParameters import PhotonBeamParameters
from SimEx.Parameters.DetectorGeometry import DetectorGeometry, DetectorPanel
from SimEx.Utilities.Units import electronvolt, joule, meter, radian
# Out:
# initializing ocelot...

# %%
SimExBin = ':/gpfs/exfel/data/user/juncheng/miniconda3/envs/simex0.5/bin/'
os.environ["PATH"] += SimExBin

# %% [markdown]
# ## Data path setup

# %%
data_path = './diffr'

# %% [markdown]
# Clean up any data from a previous run:

# %%
if os.path.isdir(data_path):
    shutil.rmtree(data_path)

if os.path.isfile(data_path + '.h5'):
    os.remove(data_path + '.h5')

# %% [markdown]
# ## Set up X-ray Beam Parameters

# %%
beamParam = PhotonBeamParameters(
    photon_energy = 4972.0 * electronvolt,  # photon energy in eV
    beam_diameter_fwhm=130e-9 * meter,      # focus diameter in m
    pulse_energy=45e-3 * joule,             # pulse energy in J
    photon_energy_relative_bandwidth=0.003, # relative bandwidth dE/E
    divergence=0.0 * radian,                # Beam divergence in rad
    photon_energy_spectrum_type='tophat',   # Spectrum type. Acceptable values are "tophat", "SASE", and "twocolor")
)

# %% [markdown]
# ## Detector Setting

# %%
geom = AGIPD_1MGeometry.from_quad_positions(quad_pos=[
    (-525, 625),
    (-550, -10),
    (520, -160),
    (542.5, 475),
])

# %%
geom.inspect()
# Out:
# <AxesSubplot:title={'center':'AGIPD-1M detector geometry (No file)'}, xlabel='pixels', ylabel='pixels'>

# %%
geom_file = 'agipd_simple_2d.geom'
geom.write_crystfel_geom(
    geom_file,
    dims=('frame', 'ss', 'fs'),
    adu_per_ev=1.0,
    clen=0.13,          # Sample - detector distance in m
    photon_energy=4972, # eV
    data_path='/data/data',
)

# %% [markdown]
# ## Diffractor Settings

# %%
diffParam = CrystFELPhotonDiffractorParameters(
    sample='3WUL.pdb',                    # Looks up pdb file in cwd, if not found, queries from RCSB pdb mirror.
    uniform_rotation=True,                # Apply random rotation
    number_of_diffraction_patterns=100,     #
    powder=False,                         # Set xto True to create a virtual powder diffraction pattern (unested)
    intensities_file=None,                # File that contains reflection intensities. If set to none, use uniform intensity distribution
    crystal_size_range=[1e-7, 1e-7],      # Range ([min,max]) in units of metres of crystal size.
    poissonize=False,                     # Set to True to add Poisson noise.
    number_of_background_photons=0,       # Change number to add uniformly distributed background photons.
    suppress_fringes=False,               # Set to True to suppress side maxima between reflection peaks.
    beam_parameters=beamParam,            # Beam parameters object from above
    detector_geometry=geom_file,          # External file that contains the detector geometry in CrystFEL notation.
)

# %%
diffractor = CrystFELPhotonDiffractor(
    parameters=diffParam, output_path=data_path
)

# %% [markdown]
# ## Run the simulation

# %%
from timeit import default_timer as timer
start = timer()

status = diffractor.backengine()

end = timer()
print(end - start,'s') # Time in seconds
if (status == 0):
    print ("Successful!")
else:
    print ("Error code:",status)
# Out:
# 1354.3393001540098 s
# Successful!

# %%
diffractor.saveH5()
# Out:
# Renaming diffr_out-1.h5 to diffr_out_0000001.h5.
# Renaming diffr_out-10.h5 to diffr_out_0000002.h5.
# Renaming diffr_out-100.h5 to diffr_out_0000003.h5.
# Renaming diffr_out-11.h5 to diffr_out_0000004.h5.
# Renaming diffr_out-12.h5 to diffr_out_0000005.h5.
# Renaming diffr_out-13.h5 to diffr_out_0000006.h5.
# Renaming diffr_out-14.h5 to diffr_out_0000007.h5.
# Renaming diffr_out-15.h5 to diffr_out_0000008.h5.
# Renaming diffr_out-16.h5 to diffr_out_0000009.h5.
# Renaming diffr_out-17.h5 to diffr_out_0000010.h5.
# Renaming diffr_out-18.h5 to diffr_out_0000011.h5.
# Renaming diffr_out-19.h5 to diffr_out_0000012.h5.
# Renaming diffr_out-2.h5 to diffr_out_0000013.h5.
# Renaming diffr_out-20.h5 to diffr_out_0000014.h5.
# Renaming diffr_out-21.h5 to diffr_out_0000015.h5.
# Renaming diffr_out-22.h5 to diffr_out_0000016.h5.
# Renaming diffr_out-23.h5 to diffr_out_0000017.h5.
# Renaming diffr_out-24.h5 to diffr_out_0000018.h5.
# Renaming diffr_out-25.h5 to diffr_out_0000019.h5.
# Renaming diffr_out-26.h5 to diffr_out_0000020.h5.
# Renaming diffr_out-27.h5 to diffr_out_0000021.h5.
# Renaming diffr_out-28.h5 to diffr_out_0000022.h5.
# Renaming diffr_out-29.h5 to diffr_out_0000023.h5.
# Renaming diffr_out-3.h5 to diffr_out_0000024.h5.
# Renaming diffr_out-30.h5 to diffr_out_0000025.h5.
# Renaming diffr_out-31.h5 to diffr_out_0000026.h5.
# Renaming diffr_out-32.h5 to diffr_out_0000027.h5.
# Renaming diffr_out-33.h5 to diffr_out_0000028.h5.
# Renaming diffr_out-34.h5 to diffr_out_0000029.h5.
# Renaming diffr_out-35.h5 to diffr_out_0000030.h5.
# Renaming diffr_out-36.h5 to diffr_out_0000031.h5.
# Renaming diffr_out-37.h5 to diffr_out_0000032.h5.
# Renaming diffr_out-38.h5 to diffr_out_0000033.h5.
# Renaming diffr_out-39.h5 to diffr_out_0000034.h5.
# Renaming diffr_out-4.h5 to diffr_out_0000035.h5.
# Renaming diffr_out-40.h5 to diffr_out_0000036.h5.
# Renaming diffr_out-41.h5 to diffr_out_0000037.h5.
# Renaming diffr_out-42.h5 to diffr_out_0000038.h5.
# Renaming diffr_out-43.h5 to diffr_out_0000039.h5.
# Renaming diffr_out-44.h5 to diffr_out_0000040.h5.
# Renaming diffr_out-45.h5 to diffr_out_0000041.h5.
# Renaming diffr_out-46.h5 to diffr_out_0000042.h5.
# Renaming diffr_out-47.h5 to diffr_out_0000043.h5.
# Renaming diffr_out-48.h5 to diffr_out_0000044.h5.
# Renaming diffr_out-49.h5 to diffr_out_0000045.h5.
# Renaming diffr_out-5.h5 to diffr_out_0000046.h5.
# Renaming diffr_out-50.h5 to diffr_out_0000047.h5.
# Renaming diffr_out-51.h5 to diffr_out_0000048.h5.
# Renaming diffr_out-52.h5 to diffr_out_0000049.h5.
# Renaming diffr_out-53.h5 to diffr_out_0000050.h5.
# Renaming diffr_out-54.h5 to diffr_out_0000051.h5.
# Renaming diffr_out-55.h5 to diffr_out_0000052.h5.
# Renaming diffr_out-56.h5 to diffr_out_0000053.h5.
# Renaming diffr_out-57.h5 to diffr_out_0000054.h5.
# Renaming diffr_out-58.h5 to diffr_out_0000055.h5.
# Renaming diffr_out-59.h5 to diffr_out_0000056.h5.
# Renaming diffr_out-6.h5 to diffr_out_0000057.h5.
# Renaming diffr_out-60.h5 to diffr_out_0000058.h5.
# Renaming diffr_out-61.h5 to diffr_out_0000059.h5.
# Renaming diffr_out-62.h5 to diffr_out_0000060.h5.
# Renaming diffr_out-63.h5 to diffr_out_0000061.h5.
# Renaming diffr_out-64.h5 to diffr_out_0000062.h5.
# Renaming diffr_out-65.h5 to diffr_out_0000063.h5.
# Renaming diffr_out-66.h5 to diffr_out_0000064.h5.
# Renaming diffr_out-67.h5 to diffr_out_0000065.h5.
# Renaming diffr_out-68.h5 to diffr_out_0000066.h5.
# Renaming diffr_out-69.h5 to diffr_out_0000067.h5.
# Renaming diffr_out-7.h5 to diffr_out_0000068.h5.
# Renaming diffr_out-70.h5 to diffr_out_0000069.h5.
# Renaming diffr_out-71.h5 to diffr_out_0000070.h5.
# Renaming diffr_out-72.h5 to diffr_out_0000071.h5.
# Renaming diffr_out-73.h5 to diffr_out_0000072.h5.
# Renaming diffr_out-74.h5 to diffr_out_0000073.h5.
# Renaming diffr_out-75.h5 to diffr_out_0000074.h5.
# Renaming diffr_out-76.h5 to diffr_out_0000075.h5.
# Renaming diffr_out-77.h5 to diffr_out_0000076.h5.
# Renaming diffr_out-78.h5 to diffr_out_0000077.h5.
# Renaming diffr_out-79.h5 to diffr_out_0000078.h5.
# Renaming diffr_out-8.h5 to diffr_out_0000079.h5.
# Renaming diffr_out-80.h5 to diffr_out_0000080.h5.
# Renaming diffr_out-81.h5 to diffr_out_0000081.h5.
# Renaming diffr_out-82.h5 to diffr_out_0000082.h5.
# Renaming diffr_out-83.h5 to diffr_out_0000083.h5.
# Renaming diffr_out-84.h5 to diffr_out_0000084.h5.
# Renaming diffr_out-85.h5 to diffr_out_0000085.h5.
# Renaming diffr_out-86.h5 to diffr_out_0000086.h5.
# Renaming diffr_out-87.h5 to diffr_out_0000087.h5.
# Renaming diffr_out-88.h5 to diffr_out_0000088.h5.
# Renaming diffr_out-89.h5 to diffr_out_0000089.h5.
# Renaming diffr_out-9.h5 to diffr_out_0000090.h5.
# Renaming diffr_out-90.h5 to diffr_out_0000091.h5.
# Renaming diffr_out-91.h5 to diffr_out_0000092.h5.
# Renaming diffr_out-92.h5 to diffr_out_0000093.h5.
# Renaming diffr_out-93.h5 to diffr_out_0000094.h5.
# Renaming diffr_out-94.h5 to diffr_out_0000095.h5.
# Renaming diffr_out-95.h5 to diffr_out_0000096.h5.
# Renaming diffr_out-96.h5 to diffr_out_0000097.h5.
# Renaming diffr_out-97.h5 to diffr_out_0000098.h5.
# Renaming diffr_out-98.h5 to diffr_out_0000099.h5.
# Renaming diffr_out-99.h5 to diffr_out_0000100.h5.
# Linking all patterns into /gpfs/exfel/data/user/juncheng/SimEx-notebooks/SFX/diffr.h5.

# %%
data_f = h5py.File(data_path + '.h5', 'r')
frame = data_f['data/0000004/data'][...].reshape(16, 512, 128)

fig, ax = plt.subplots(figsize=(12, 10))
geom.plot_data_fast(frame, axis_units='m', ax=ax, vmax=1000);

# %% [markdown]
# This project has received funding from the European Union's Horizon 2020 research and innovation programme under grant agreement No. 823852.
